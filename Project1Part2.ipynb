# %%
## importing the libraries
import numpy as np #Numerical analysis
import pandas as pd ##For data manupulation

# %% [markdown]
# ## Data Loading

# %%
pd.read_csv(r"C:\Users\LUKMAN ADEOLA\JULY PHYTHON CLASS\Projects\Data1-Loan.csv")
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan=pd.read_csv(r"C:\Users\LUKMAN ADEOLA\JULY PHYTHON CLASS\Projects\Data1-Loan.csv")

# %%
loan.head
# Out:
# <bound method NDFrame.head of       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#first five records

loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan.head(100)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# ..       ...     ...     ...        ...           ...           ...
# 95  LP001326    Male      No          0      Graduate           NaN
# 96  LP001327  Female     Yes          0      Graduate            No
# 97  LP001333    Male     Yes          0      Graduate            No
# 98  LP001334    Male     Yes          0  Not Graduate            No
# 99  LP001343    Male     Yes          0      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0         NaN             360.0
# ...

# %%
#Last five records

loan.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
## checking the shape of the data

loan.shape
# Out:
# (614, 13)

# %%
## Check data type
loan.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
## More insight about the data
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# ## Data Cleaning

# %%
## chek for blanks/null
loan.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
## chek for blanks/null
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Use mean,mode,median to handle blanks

# %% [markdown]
# ### Example fill missing vaues with unknown

# %% [raw]
# loan.fillna('unknown',inplace=True)
#
# #do not execute-- Will not work

# %% [markdown]
# #### Example fill missing vaues with unknown
# loan.fillna('unknown') #do not execute-- will not apply to the table without inplace/add inplace

# %% [raw]
# loan.fillna('Not Found',inplace=True) #- this will change permaently but do not excute
# Every blanks in all the column will change to not found
# handly the nulls individually

# %%
## Now fill the null properly

# %%
## chek for blanks/null
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ## Gender column

# %%
# Value count of gender types

# %%
loan['Gender'].value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
## Fill balnks with unknown

loan.fillna({'Gender':'Unknown'},inplace=True)

# %%
loan['Gender'].value_counts()
# Out:
# Gender
# Male       489
# Female     112
# Unknown     13
# Name: count, dtype: int64

# %%
## chek for blanks/null
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ## Married Column

# %%
## check for blanks/null
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
## Value count of married types

loan['Married'].value_counts()  # with 3 blanks
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %% [markdown]
# ##Example
# loan=614 rows
#
# married column
#
# married=398
# not mrried=213
# unknown=3 -- replace with mode
#
#
# wedding guest 600
# married=250   not married=250  unknown=100  -- Unknown will be replace with the first count of married column,married and not married has same
# count.if unknown is being replace with mode.the first one to reach the mode will be replace....if married hit 250 first unknown will be equals to
# married but if unmarried hit 250 first unknown it will be equals to
# unmarried

# %%
## we replace blanks with mode(3 blanks)

loan['Married'] = loan['Married'].fillna(loan['Married'].mode()[0])

# %%
## Value count of married types

loan['Married'].value_counts()
# Out:
# Married
# Yes    401
# No     213
# Name: count, dtype: int64

# %%
## check for blanks/null
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
## Check data type
loan.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %% [markdown]
# ## Dependent column

# %%
## check for blanks/null
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
## Value count of dependents types

loan['Dependents'].value_counts()
# Out:
# Dependents
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
# Removing non digit value (+) we have 3+ Replace that

loan['Dependents']=loan['Dependents'].str.extract(r'(\d+)')

# or try replace method  oe right strip
# OR loan['Dependents']=loan['Dependents'].str.replace('+', '', regex=False)

## To change a data to numeric we use:loan['Dependents'] = pd.to_numeric(loan['Dependents'])

# %%
## Value count of married types

loan['Dependents'].value_counts()
# Out:
# Dependents
# 0    345
# 1    102
# 2    101
# 3     51
# Name: count, dtype: int64

# %%
## Dependent column
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
## REplace null with mode

loan['Dependents'] = loan['Dependents'].fillna(loan['Dependents'].mode()[0])

# %%
## Value count of Dependents types

loan['Dependents'].value_counts()
# Out:
# Dependents
# 0    360
# 1    102
# 2    101
# 3     51
# Name: count, dtype: int64

# %%
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ## Education Column

# %%
## check for blanks/null

loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
## Value count of dependents types

loan['Education'].value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %% [markdown]
# ## Self employed

# %%
## check for blanks/null
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
## Value count of married types

loan['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No     500
# Yes     82
# Name: count, dtype: int64

# %%
## Replace null with unknown #32 blank is alot,change it to unknown

loan.fillna({'Self_Employed':'Unknown'},inplace=True)

# %%
## Value count of Self_Employed types

loan['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No         500
# Yes         82
# Unknown     32
# Name: count, dtype: int64

# %%
## check for blanks/null
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# ApplicantIncome

loan['ApplicantIncome'].value_counts()
# Out:
# ApplicantIncome
# 2500    9
# 4583    6
# 6000    6
# 2600    6
# 3333    5
#        ..
# 3244    1
# 4408    1
# 3917    1
# 3992    1
# 7583    1
# Name: count, Length: 505, dtype: int64

# %%
loan.agg(
    total_ApplicantIncome=('ApplicantIncome', 'sum'),
    avg_ApplicantIncome=('ApplicantIncome', 'mean'),
    Minimum_ApplicantIncome=('ApplicantIncome', 'min'),
    Maximum_ApplicantIncome=('ApplicantIncome', 'max')
).round(1)
# Out:
#                          ApplicantIncome
# total_ApplicantIncome          3317724.0
# avg_ApplicantIncome               5403.5
# Minimum_ApplicantIncome            150.0
# Maximum_ApplicantIncome          81000.0

# %%
loan[['ApplicantIncome']].agg(['sum', 'mean', 'min', 'max']).round(1)
# Out:
#       ApplicantIncome
# sum         3317724.0
# mean           5403.5
# min             150.0
# max           81000.0

# %% [markdown]
# ### CoapplicantIncome

# %%
loan['CoapplicantIncome'].value_counts()
# Out:
# CoapplicantIncome
# 0.0       273
# 2500.0      5
# 2083.0      5
# 1666.0      5
# 2250.0      3
#          ...
# 2791.0      1
# 1010.0      1
# 1695.0      1
# 2598.0      1
# 240.0       1
# Name: count, Length: 287, dtype: int64

# %%
loan.agg(
    total_CoapplicantIncome=('CoapplicantIncome', 'sum'),
    avg_CoapplicantIncome=('CoapplicantIncome', 'mean'),
    Minimum_CoapplicantIncome=('CoapplicantIncome', 'min'),
    Maximum_CoapplicantIncome=('CoapplicantIncome', 'max')
).round(1)
# Out:
#                            CoapplicantIncome
# total_CoapplicantIncome             995444.9
# avg_CoapplicantIncome                 1621.2
# Minimum_CoapplicantIncome                0.0
# Maximum_CoapplicantIncome            41667.0

# %%
# OR

loan[['CoapplicantIncome']].agg(['sum', 'mean', 'min', 'max']).round(1)
# Out:
#       CoapplicantIncome
# sum            995444.9
# mean             1621.2
# min                 0.0
# max             41667.0

# %% [markdown]
# ## Loan amount column

# %%
## check for blanks/null
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
 ## Value count of  types

loan['LoanAmount'].value_counts()
# Out:
# LoanAmount
# 120.0    20
# 110.0    17
# 100.0    15
# 160.0    12
# 187.0    12
#          ..
# 240.0     1
# 214.0     1
# 59.0      1
# 166.0     1
# 253.0     1
# Name: count, Length: 203, dtype: int64

# %%
# Replacing loan amount missing values with average

loan['LoanAmount'] = loan['LoanAmount'].fillna(loan['LoanAmount'].mean())

# %%
loan['LoanAmount'].value_counts()
# Out:
# LoanAmount
# 146.412162    22
# 120.000000    20
# 110.000000    17
# 100.000000    15
# 160.000000    12
#               ..
# 240.000000     1
# 214.000000     1
# 59.000000      1
# 166.000000     1
# 253.000000     1
# Name: count, Length: 204, dtype: int64

# %%
loan[['LoanAmount']].agg(['sum', 'mean', 'min', 'max']).round(1)
# Out:
#       LoanAmount
# sum      89897.1
# mean       146.4
# min          9.0
# max        700.0

# %%
## check if no more blanks
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ## Loan Amount Term

# %%
## check for blanks/null
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
 ## Value count of  Loan_Amount_Term

loan['Loan_Amount_Term'].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
## REplace null with mode

loan['Loan_Amount_Term'] = loan['Loan_Amount_Term'].fillna(loan['Loan_Amount_Term'].mode()[0])

# %%
loan['Loan_Amount_Term'].value_counts()
# Out:
# Loan_Amount_Term
# 360.0    526
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: count, dtype: int64

# %%
loan[['Loan_Amount_Term']].agg(['sum', 'mean', 'min', 'max']).round(1)
# Out:
#       Loan_Amount_Term
# sum           210240.0
# mean             342.4
# min               12.0
# max              480.0

# %%
## check if no more blanks
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ## Credit_History

# %%
## check for blanks/null
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
 ## Value count of  types

loan['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    475
# 0.0     89
# Name: count, dtype: int64

# %%
## REplace null with mode

loan['Credit_History'] = loan['Credit_History'].fillna(loan['Credit_History'].mode()[0])

# loan.fillna({'Credit_History':1.0},inplace=True)

# %%
loan['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    525
# 0.0     89
# Name: count, dtype: int64

# %%
## check if no more blanks
loan.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# ### Property_Area

# %%
loan['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %% [markdown]
# ### Loan_Status

# %%
loan['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %% [raw]
# #### Assignment
#
# 800000
#
# Tax 7.5
# 750K

# %% [markdown]
# #### Day2

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %% [markdown]
# ### Dropping unwanted column

# %%
loan.drop(columns=['Loan_ID','Loan_Status'])  ##  Will not remove column permanetly
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes          3      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df=loan.drop(columns=['Loan_ID','Loan_Status'])  

## This will remove both column since variables has been applied

# %%
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
## DROP only loan_id

df=loan.drop(columns=[('Loan_ID')])

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %% [markdown]
# ## Data Visualization

# %%
# !pip install sweetviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
## univarite analysis chart
import sweetviz as sv

# %%
my_report=sv.analyze(df)
## my_report_show_html('insights')
## my_report.show_html('insights') # Need external app to open-- Use and see

my_report.show_notebook()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
## ## matpolib,seaborn -- For DATA VISUALIZATION

import matplotlib.pyplot as pit
import seaborn as sns

# %% [markdown]
# ### Gender distribution

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
## Gender distribution
## To remove the syntax value label


sns.countplot(x='Gender',data=df);   ## End the stATEament

# %%
## Add Labels

ax=sns.countplot(x='Gender',data=df);
ax.bar_label(ax.containers[0]);   # This add the labelling

# %%
## Style Chart:Add colour

ax=sns.countplot(x='Gender',data=df,palette='Greens');

ax.bar_label(ax.containers[0]);   # This add the labelling
# Out:
# C:\Users\LUKMAN ADEOLA\AppData\Local\Temp\ipykernel_2020\604159808.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x='Gender',data=df,palette='Greens');

# %%
#That's a seaborn deprecation warning, not an error — your chart still renders fine, 
#but seaborn wants you to explicitly assign the column to hue when using palette, since future versions will require it. Fix:

ax = sns.countplot(x='Gender', data=df, hue='Gender', palette='Greens', legend=False)

#hue='Gender' — tells seaborn to map colors based on that same column
#legend=False — suppresses the redundant legend that would otherwise pop up 
#(since x and hue are now the same variable, the legend would just repeat the x-axis labels)

# %%
## Style Chart

ax=sns.countplot(x='Gender',data=df,palette='Greens',hue='Loan_Status');

# %%
## Style Chart

ax=sns.countplot(x='Gender',data=df,palette='Greens',hue='Loan_Status');
ax.bar_label(ax.containers[0]);

# %%
## Style Chart
import matplotlib.pyplot as plt
import seaborn as sns

ax = sns.countplot(x='Gender', data=df, palette='Greens', hue='Loan_Status');

#  add labels to each bar group
for container in ax.containers:
    ax.bar_label(ax.containers[0])

# Add title outside the chart
plt.title('Gender Distribution by Loan Status');

# %% [markdown]
# ### Married by eductional status

# %%
ax=sns.countplot(x='Married',data=df)

# %%
ax=sns.countplot(x='Married',data=df,palette='Reds')
# Out:
# C:\Users\LUKMAN ADEOLA\AppData\Local\Temp\ipykernel_2020\2997015581.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(x='Married',data=df,palette='Reds')

# %%
ax=sns.countplot(x='Married',data=df,palette='Reds',hue='Married',legend=False)  ## Try this later

# %%
## Gender by Education

ax=sns.countplot(x='Married',data=df,palette='Reds',hue='Education')

# %%
## Style Chart

ax=sns.countplot(x='Married',data=df,palette='Reds',hue='Education')
for containers in ax.containers:
    ax.bar_label(ax.containers[0])
    plt.title('Gender Distribution by Education'); ## Title

# %% [markdown]
# ### Scatter Plot

# %%
## 'ApplicantIncome' by 'LoanAmount'

sns.scatterplot(data=df,x='ApplicantIncome',y='LoanAmount',palette='Greens',hue='LoanAmount');

# %%
sns.scatterplot(data=df,x='ApplicantIncome',y='LoanAmount',palette='viridis',hue='LoanAmount')
## Add title

plt.title('ApplicantIncome by LoanAmount');

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %% [markdown]
# #### Pie chart

# %%
## Avg Salary by eduction
income = df.groupby('Education')['ApplicantIncome'].mean()
income
# Out:
# Education
# Graduate        5857.433333
# Not Graduate    3777.283582
# Name: ApplicantIncome, dtype: float64

# %%
## Avg loan by eduction

Loan = df.groupby('Education')['LoanAmount'].mean()
income
# Out:
# Education
# Graduate        5857.433333
# Not Graduate    3777.283582
# Name: ApplicantIncome, dtype: float64

# %%
## Avg Salary by eduction
income = df.groupby('Education')['ApplicantIncome'].mean()
income
# Out:
# Education
# Graduate        5857.433333
# Not Graduate    3777.283582
# Name: ApplicantIncome, dtype: float64

# %%
#pie chart, no labels

import matplotlib.pyplot as plt
#  pie chart using your income variable
plt.pie(income);

# %%
plt.pie(income, labels=income.index, autopct='%1.1f%%')
plt.title('Total Applicant Income by Education');

# %% [markdown]
# #### Building dashboard

# %%
## First you define the rows and columns

fig, axs=plt.subplots(2,2,figsize=(10,10))

# %%
## First you define the rows and columns
fig, axs = plt.subplots(2, 2, figsize=(10,8))   #define 2x2 grid of subplots

#(top-left): Gender counts by Loan Status
ax = sns.countplot(x='Gender', data=df, palette='Greens', hue='Loan_Status', ax=axs[0, 0])
for container in ax.containers:
    ax.bar_label(container)  # Add labels to bars

# Set title outside the loop
ax.set_title('Gender Distribution by Loan Status');

# %%
## Chart1 and 2

## First you define the rows and columns

fig, axs=plt.subplots(2,2,figsize=(10,8))


#### First Chart-we use index 0,0 for our first subplot
ax1=sns.countplot(x='Gender',data=df,palette='Greens',hue='Loan_Status',ax=axs[0,0])
# ax.bar_label(ax.containers[0]);
# for values in our bar chart

for container in ax1.containers:
    ax1.bar_label(container)

    # Adding the title for our chart
    axs[0,0].set_title('Count plot of Gender by Loan Status')


#### Second Chart,using index 1,1
sns.scatterplot(data=df, x='ApplicantIncome', y='LoanAmount', palette='viridis', hue='Loan_Status', ax=axs[1, 1])
axs[1, 1].set_title('Applicant Income vs Loan Amount');

# %%
## Chart1,2 amd 3

## First you define the rows and columns

fig, axs=plt.subplots(2,2,figsize=(10,8))


#### First Chart-we use index 0,0 for our first subplot
ax1=sns.countplot(x='Gender',data=df,palette='Greens',hue='Loan_Status',ax=axs[0,0])
# ax.bar_label(ax.containers[0]);
# for values in our bar chart

for container in ax1.containers:
    ax1.bar_label(container)

    # Adding the title for our chart
    axs[0,0].set_title('Count plot of Gender by Loan Status')


#### Second Chart,using index 1,1
sns.scatterplot(data=df, x='ApplicantIncome', y='LoanAmount', palette='viridis', hue='Loan_Status', ax=axs[1, 1])
axs[1, 1].set_title('Applicant Income vs Loan Amount')


#### Third Chart,using index 0,1
ax=sns.countplot(x='Married',data=df,palette='Reds',hue='Education',ax=axs[0,1])
for container in ax.containers:
    ax.bar_label(container)

axs[0,1].set_title('Married Status by Education')
# Out:
# Text(0.5, 1.0, 'Married Status by Education')

# %%
# Export cleaned data to CSV in the current working directory
df.to_csv('Loan_class.csvnew', index=False)

# %%
## Chart1,2,3 and 4

## First you define the rows and columns

fig, axs=plt.subplots(2,2,figsize=(10,8))


#### First Chart-we use index 0,0 for our first subplot
ax1=sns.countplot(x='Gender',data=df,palette='Greens',hue='Loan_Status',ax=axs[0,0])
# ax.bar_label(ax.containers[0]);
# for values in our bar chart

for container in ax1.containers:
    ax1.bar_label(container)

    # Adding the title for our chart
    axs[0,0].set_title('Count plot of Gender by Loan Status')


#### Second Chart,using index 1,1
sns.scatterplot(data=df, x='ApplicantIncome', y='LoanAmount', palette='viridis', hue='Loan_Status', ax=axs[1, 1])
axs[1, 1].set_title('Applicant Income vs Loan Amount')


#### Third Chart,using index 0,1
ax=sns.countplot(x='Married',data=df,palette='Reds',hue='Education',ax=axs[0,1])
for container in ax.containers:
    ax.bar_label(container)

axs[0,1].set_title('Married Status by Education')


#### Fourth Chart
axs[1,0].pie(income,labels=income.index, autopct='%1.0f%%');

axs[1,0].set_title('Applicant Income by Education ');

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
# Export cleaned data to CSV in the current working directory
df.to_csv('Loan_class.csv', index=False)

# %%
# Export to a specific path — update this path for your own system
df.to_csv(r'C:\Users\LUKMAN ADEOLA\JULY PHYTHON CLASS\Projects\Loan_Project_Clean.csv', index=False)

# %%
# Export to Excel .xlsx requires openpyxl installed
df.to_excel(r'C:\Users\LUKMAN ADEOLA\JULY PHYTHON CLASS\Projects\Loan_Project_Clean..xlsx', index=False)

# %% [raw]
# ### Assignment
# Build a report with a 3*3 subplots

# %% [markdown]
# ### ASSIGNMENT

# %%
# [0,0] Gender counts, split by Loan_Status
ax = sns.countplot(x='Gender', data=df, palette='Greens', hue='Loan_Status')
for container in ax.containers:
    ax.bar_label(container)
ax.set_title('Gender by Loan Status')
# Out:
# Text(0.5, 1.0, 'Gender by Loan Status')

# %%
# [0,1] Married status, split by Education
ax = sns.countplot(x='Married', data=df, palette='Reds', hue='Education')
for container in ax.containers:
    ax.bar_label(container)
ax.set_title('Married Status by Education')
# Out:
# Text(0.5, 1.0, 'Married Status by Education')

# %%
# [0,2] Education counts, split by Loan_Status
ax = sns.countplot(x='Education', data=df, palette='Blues', hue='Loan_Status')
for container in ax.containers:
    ax.bar_label(containers)
ax.set_title('Education by Loan Status')
# Out:
# Text(0.5, 1.0, 'Education by Loan Status')

# %%
# [1,1] Self-employed vs not
ax = sns.countplot(x='Self_Employed', data=df, palette='Greens',hue='Loan_Status')
for container in ax.containers:
    ax.bar_label(container)
ax.set_title('Self-Employed Status')
# Out:
# Text(0.5, 1.0, 'Self-Employed Status')

# %%
# [1,0] Distribution of number of dependents
ax = sns.countplot(x='Dependents', data=df,palette='Purples',hue='Loan_Status')
for container in ax.containers:
    ax.bar_label(container)
ax.set_title('Number of Dependents')
# Out:
# Text(0.5, 1.0, 'Number of Dependents')

# %%
# [2,0] Credit history distribution
ax = sns.countplot(x='Credit_History', data=df, palette='Greys',hue='Loan_Status')
for container in ax.containers:
    ax.bar_label(container)
ax.set_title('Credit History')
# Out:
# Text(0.5, 1.0, 'Credit History')

# %%
# [2,2] Overall loan approval rate
loan_status_counts = df['Loan_Status'].value_counts()


plt.pie(loan_status_counts, labels=loan_status_counts.index, autopct='%1.0f%%')
plt.title('Loan Status Approval Rate')
# Out:
# Text(0.5, 1.0, 'Loan Status Approval Rate')

# %%
fig, axs = plt.subplots(3, 3, figsize=(18, 14))

# [0,0] Gender by Loan Status
ax = sns.countplot(x='Gender', data=df, palette='Greens', hue='Loan_Status', ax=axs[0, 0])
for container in ax.containers:
    ax.bar_label(container)
axs[0, 0].set_title('Gender by Loan Status')

# [0,1] Married by Education
ax = sns.countplot(x='Married', data=df, palette='Reds', hue='Education', ax=axs[0, 1])
for container in ax.containers:
    ax.bar_label(container)
axs[0, 1].set_title('Married Status by Education')

# [0,2] Education by Loan Status
ax = sns.countplot(x='Education', data=df, palette='Blues', hue='Loan_Status', ax=axs[0, 2])
for container in ax.containers:
    ax.bar_label(container)
axs[0, 2].set_title('Education by Loan Status')

# [1,0] Dependents
ax = sns.countplot(x='Dependents', data=df, palette='Purples',hue='Loan_Status', ax=axs[1, 0])
ax.bar_label(ax.containers[0])
axs[1, 0].set_title('Number of Dependents')

# [1,1] Self-Employed
ax = sns.countplot(x='Self_Employed', data=df, palette='Oranges',hue='Loan_Status', ax=axs[1, 1])
ax.bar_label(ax.containers[0])
axs[1, 1].set_title('Self-Employed Status')

# [1,2] Property Area by Loan Status
ax = sns.countplot(x='Property_Area', data=df, palette='Greens', hue='Loan_Status', ax=axs[1, 2])
for container in ax.containers:
    ax.bar_label(container)
axs[1, 2].set_title('Property Area by Loan Status')

# [2,0] Credit History
ax = sns.countplot(x='Credit_History', data=df, palette='Greys',hue='Loan_Status',ax=axs[2, 0])
ax.bar_label(ax.containers[0])
axs[2, 0].set_title('Credit History')

# [2,1] Applicant Income vs Loan Amount
sns.scatterplot(data=df, x='ApplicantIncome', y='LoanAmount', hue='LoanAmount',
                 palette='viridis', ax=axs[2, 1])
axs[2, 1].set_title('Applicant Income vs Loan Amount')

# [2,2] Loan Status approval rate
loan_status_counts = df['Loan_Status'].value_counts()
axs[2, 2].pie(loan_status_counts, labels=loan_status_counts.index, autopct='%1.0f%%')
axs[2, 2].set_title('Loan Status Approval Rate')

fig.suptitle('Loan Applicant Dashboard', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Machine Learning

# %% [raw]
# cv=5
#
# 100,000 records
#
# 20,000 test
# 80,000 train
#
# 80K/5
#
#
# 16,000,16,000,16,000,16,000

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
# Import the scaler:
# without scaling, a column like TotalAmount (hundreds/thousands) 
# would dominate a column like Quantity (single digits)
# purely because of its size, not its real predictive importance.

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()  ## Initiate Standard scaler

# %%
df['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    525
# 0.0     89
# Name: count, dtype: int64

# %% [raw]
# Credit_History — this looks binary (0.0/1.0), so scaling it doesn't
# really do anything meaningful and can make it harder to interpret later.
#
# Dependents — typically small integers (0–3+), low variance, not really a "dominating scale" column.
#
# Loan_Amount_Term — this one does have larger values (e.g. 360), so scaling it is reasonable.
#
# Meanwhile ApplicantIncome, CoapplicantIncome, and LoanAmount CAN SCALES
#
# leave Credit_History (binary) and Dependents (small counts, possibly categorical) out

# %%
### List the columns to standardize

numeric_cols = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

# %%
## Print numeric_cols

numeric_cols
# Out:
# ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

# %%
sales_scaled=df.copy()

# %%
sales_scaled.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
#  Initialize scaler and transform df2

scaler = StandardScaler()   

sales_scaled[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
sales_scaled[numeric_cols]
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# 0           0.072991          -0.554487    0.000000          0.273231
# 1          -0.134412          -0.038732   -0.219273          0.273231
# 2          -0.393747          -0.554487   -0.957641          0.273231
# 3          -0.462062           0.251980   -0.314547          0.273231
# 4           0.097728          -0.554487   -0.064454          0.273231
# ..               ...                ...         ...               ...
# 609        -0.410130          -0.554487   -0.898095          0.273231
# 610        -0.212557          -0.554487   -1.267279         -2.522836
# 611         0.437174          -0.472404    1.269371          0.273231
# 612         0.357064          -0.554487    0.483367          0.273231
# 613        -0.134412          -0.554487   -0.159728          0.273231
#
# [614 rows x 4 columns]

# %%
sales_scaled.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No         0.072991
# 1   Male     Yes          1      Graduate            No        -0.134412
# 2   Male     Yes          0      Graduate           Yes        -0.393747
# 3   Male     Yes          0  Not Graduate            No        -0.462062
# 4   Male      No          0      Graduate            No         0.097728
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          -0.554487    0.000000          0.273231             1.0
# 1          -0.038732   -0.219273          0.273231             1.0
# 2          -0.554487   -0.957641          0.273231             1.0
# 3           0.251980   -0.314547          0.273231             1.0
# 4          -0.554487   -0.064454          0.273231             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
sales_scaled['Gender'].value_counts()
# Out:
# Gender
# Male       489
# Female     112
# Unknown     13
# Name: count, dtype: int64

# %%
sales_scaled['Married'].value_counts()
# Out:
# Married
# Yes    401
# No     213
# Name: count, dtype: int64

# %%
sales_scaled['Dependents'].value_counts()
# Out:
# Dependents
# 0    360
# 1    102
# 2    101
# 3     51
# Name: count, dtype: int64

# %%
sales_scaled['Education'].value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
sales_scaled['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No         500
# Yes         82
# Unknown     32
# Name: count, dtype: int64

# %%
sales_scaled['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
sales_scaled['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
sales_scaled.replace({
    'Gender':{'Female':0, 'Male':1,'Unknown':1},
    'Married':{'No':0, 'Yes':1},
    'Education':{'Not Graduate':0, 'Graduate':1},
    'Self_Employed':{'No':0, 'Yes':1,'Unknown':0}
}, inplace=True)
# Out:
# C:\Users\LUKMAN ADEOLA\AppData\Local\Temp\ipykernel_2020\3493865058.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   sales_scaled.replace({

# %%
## How to turn off warning permanently:opt into the future default globally 
# (silences it for the whole notebook):


pd.set_option('future.no_silent_downcasting', True)

# %%
sales_scaled.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          1              0         0.072991
# 1       1        1          1          1              0        -0.134412
# 2       1        1          0          1              1        -0.393747
# 3       1        1          0          0              0        -0.462062
# 4       1        0          0          1              0         0.097728
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          -0.554487    0.000000          0.273231             1.0
# 1          -0.038732   -0.219273          0.273231             1.0
# 2          -0.554487   -0.957641          0.273231             1.0
# 3           0.251980   -0.314547          0.273231             1.0
# 4          -0.554487   -0.064454          0.273231             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
## Using pd.get dummies for the property_area

dummies=pd.get_dummies(sales_scaled['Property_Area'], dtype=int)

# %%
dummies.head()
# Out:
#    Rural  Semiurban  Urban
# 0      0          0      1
# 1      1          0      0
# 2      0          0      1
# 3      0          0      1
# 4      0          0      1

# %%
sales_scaled.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          1              0         0.072991
# 1       1        1          1          1              0        -0.134412
# 2       1        1          0          1              1        -0.393747
# 3       1        1          0          0              0        -0.462062
# 4       1        0          0          1              0         0.097728
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          -0.554487    0.000000          0.273231             1.0
# 1          -0.038732   -0.219273          0.273231             1.0
# 2          -0.554487   -0.957641          0.273231             1.0
# 3           0.251980   -0.314547          0.273231             1.0
# 4          -0.554487   -0.064454          0.273231             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
## concatingthe dummies column with the df

# sales_scaled = pd.concat([sales_scaled.drop(columns=['Property_Area']), dummies], axis=1)

sales_scaled2=pd.get_dummies(sales_scaled,columns=['Property_Area'],drop_first=False, dtype=int)

# %%
sales_scaled2.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          1              0         0.072991
# 1       1        1          1          1              0        -0.134412
# 2       1        1          0          1              1        -0.393747
# 3       1        1          0          0              0        -0.462062
# 4       1        0          0          1              0         0.097728
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          -0.554487    0.000000          0.273231             1.0
# 1          -0.038732   -0.219273          0.273231             1.0
# 2          -0.554487   -0.957641          0.273231             1.0
# 3           0.251980   -0.314547          0.273231             1.0
# 4          -0.554487   -0.064454          0.273231             1.0
#
#   Loan_Status  Property_Area_Rural  Property_Area_Semiurban  \
# ...

# %%
## Pop loan status to the end

sales_scaled2['Loan_Status'] = sales_scaled2.pop('Loan_Status')

# %%
sales_scaled2.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          1              0         0.072991
# 1       1        1          1          1              0        -0.134412
# 2       1        1          0          1              1        -0.393747
# 3       1        1          0          0              0        -0.462062
# 4       1        0          0          1              0         0.097728
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          -0.554487    0.000000          0.273231             1.0
# 1          -0.038732   -0.219273          0.273231             1.0
# 2          -0.554487   -0.957641          0.273231             1.0
# 3           0.251980   -0.314547          0.273231             1.0
# 4          -0.554487   -0.064454          0.273231             1.0
#
#    Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban  \
# ...

# %%
## converting the loan status to 0 & 1

sales_scaled2.replace({'Loan_Status':{'N':0, 'Y':1}}, inplace=True)

# %%
sales_scaled2.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          1              0         0.072991
# 1       1        1          1          1              0        -0.134412
# 2       1        1          0          1              1        -0.393747
# 3       1        1          0          0              0        -0.462062
# 4       1        0          0          1              0         0.097728
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          -0.554487    0.000000          0.273231             1.0
# 1          -0.038732   -0.219273          0.273231             1.0
# 2          -0.554487   -0.957641          0.273231             1.0
# 3           0.251980   -0.314547          0.273231             1.0
# 4          -0.554487   -0.064454          0.273231             1.0
#
#    Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban  \
# ...

# %%
df=sales_scaled2.copy()

# %%
df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          1              0         0.072991
# 1       1        1          1          1              0        -0.134412
# 2       1        1          0          1              1        -0.393747
# 3       1        1          0          0              0        -0.462062
# 4       1        0          0          1              0         0.097728
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          -0.554487    0.000000          0.273231             1.0
# 1          -0.038732   -0.219273          0.273231             1.0
# 2          -0.554487   -0.957641          0.273231             1.0
# 3           0.251980   -0.314547          0.273231             1.0
# 4          -0.554487   -0.064454          0.273231             1.0
#
#    Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   614 non-null    int64
#  1   Married                  614 non-null    int64
#  2   Dependents               614 non-null    object
#  3   Education                614 non-null    int64
#  4   Self_Employed            614 non-null    int64
#  5   ApplicantIncome          614 non-null    float64
#  6   CoapplicantIncome        614 non-null    float64
#  7   LoanAmount               614 non-null    float64
#  8   Loan_Amount_Term         614 non-null    float64
#  9   Credit_History           614 non-null    float64
#  10  Property_Area_Rural      614 non-null    int64
#  11  Property_Area_Semiurban  614 non-null    int64
#  12  Property_Area_Urban      614 non-null    int64
#  13  Loan_Status              614 non-null    object
# ...

# %%
## Converting gender,dependent,self-employed column to integer
df['Gender']=df['Gender'].astype('int64') 
df['Dependents']=df['Dependents'].astype('int64') 
df['Married']=df['Married'].astype('int64') 
df['Education']=df['Education'].astype('int64') 
df['Self_Employed']=df['Self_Employed'].astype('int64') 
df['Loan_Status']=df['Loan_Status'].astype('int64')
df['Loan_Amount_Term']=df['Loan_Amount_Term'].astype('int64')
df['Credit_History']=df['Credit_History'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   614 non-null    int64
#  1   Married                  614 non-null    int64
#  2   Dependents               614 non-null    int64
#  3   Education                614 non-null    int64
#  4   Self_Employed            614 non-null    int64
#  5   ApplicantIncome          614 non-null    float64
#  6   CoapplicantIncome        614 non-null    float64
#  7   LoanAmount               614 non-null    float64
#  8   Loan_Amount_Term         614 non-null    int64
#  9   Credit_History           614 non-null    int64
#  10  Property_Area_Rural      614 non-null    int64
#  11  Property_Area_Semiurban  614 non-null    int64
#  12  Property_Area_Urban      614 non-null    int64
#  13  Loan_Status              614 non-null    int64
# ...

# %%
df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# 1    422
# 0    192
# Name: count, dtype: int64

# %%
## Seperating features from the target(output)

x=df.drop(columns='Loan_Status')

y=df['Loan_Status']

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
x
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          1              0         0.072991
# 1         1        1           1          1              0        -0.134412
# 2         1        1           0          1              1        -0.393747
# 3         1        1           0          0              0        -0.462062
# 4         1        0           0          1              0         0.097728
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0        -0.410130
# 610       1        1           3          1              0        -0.212557
# 611       1        1           1          1              0         0.437174
# 612       1        1           2          1              0         0.357064
# 613       0        0           0          1              1        -0.134412
#
# ...

# %% [markdown]
# ### Train Test Split

# %%
## splitting the data into training and test data

## Train Test Split librray

from sklearn.model_selection import train_test_split

# %%
## train test split data

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=5)

# %%
loan.shape,df.shape,x_train.shape,x_test.shape
# Out:
# ((614, 13), (614, 14), (491, 13), (123, 13))

# %%
## model for our prediction

from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression(max_iter=10000)

# %% [markdown]
# ## To avoid data leakage  model.fit_transform
#
# model.fit(x_train,y_train)

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
## Importing my accuracy 

from sklearn.metrics  import accuracy_score

# %%
## X Train Predicsion

x_train_prediction=model.predict(x_train)

# %%
## training data accuracy

train_data_accuracy=accuracy_score(y_train,x_train_prediction)

# %%
print('Training Data Accuracy:',train_data_accuracy)
# Out:
# Training Data Accuracy: 0.8167006109979633

# %%
## X TEST PREDICTION

x_test_prediction=model.predict(x_test)

# %%
## training data accuracy

test_data_accuracy=accuracy_score(y_test,x_test_prediction)

# %%
print('Test Data Accuracy:',test_data_accuracy)
# Out:
# Test Data Accuracy: 0.7967479674796748

# %% [markdown]
# ### Pickle

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\LUKMAN ADEOLA\JULY PHYTHON CLASS\ML

# %%
#!pip install pickle

# %%
import pickle

# %%
import  os

os.chdir(r'C:\Users\LUKMAN ADEOLA\JULY PHYTHON CLASS\ML')
print("New Working Directory",os.getcwd())
# Out:
# New Working Directory C:\Users\LUKMAN ADEOLA\JULY PHYTHON CLASS\ML

# %%
## saving our model into a pickle

pickle.dump(model, open('model.sav', 'wb'))   # wb == write binary

# %%
## model that will be call in our web app

load_model = pickle.load(open('model.sav', 'rb'))    # rb = read binary

# %%
load_model
# Out:
# LogisticRegression(max_iter=10000)

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          1              0         0.072991
# 1       1        1           1          1              0        -0.134412
# 2       1        1           0          1              1        -0.393747
# 3       1        1           0          0              0        -0.462062
# 4       1        0           0          1              0         0.097728
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0          -0.554487    0.000000                 0               1
# 1          -0.038732   -0.219273                 0               1
# 2          -0.554487   -0.957641                 0               1
# 3           0.251980   -0.314547                 0               1
# 4          -0.554487   -0.064454                 0               1
#
#    Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban  \
# ...

# %%
# !pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# ### Bulding a Predictive system

# %%
input_data = (1,0,0,1,0,5849,0.0,146.412162,360,1.0,0,0,1)


import pandas as pd

columns = x_train.columns  # same columns used during training
input_df = pd.DataFrame([input_data], columns=columns)

prediction = model.predict(input_df)
print(prediction)

#0R 
## converting the input data to a numpy array
#convert_data_to_numpy = np.array(input_data)
## reshaping since we're predicting for a single instance
#reshaping_input_data = convert_data_to_numpy.reshape(1,-1)

#prediction =model.predict(reshaping_input_data)
#print(prediction)



## writing a conditional statement for our prediction
if prediction[0] == 0:
    print('Sorry you are not eligible for the loan')
else:
    print('Congratulations you are eligible for loan')
# Out:
# [1]
# Congratulations you are eligible for loan

# %%
df.to.csv('clean_loan.csv',index=False)  ## remove the index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2020\961537183.py in ?()
# ----> 1 df.to.csv('clean_loan.csv',index=False)  ## remove the index
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to'

# %%
input_data=(1,1,1,1,0,4583,1508.0,128.000000,360,1.0,1,0,0)

	
import pandas as pd

columns = x_train.columns  # same columns used during training
input_df = pd.DataFrame([input_data], columns=columns)

prediction = model.predict(input_df)
print(prediction)

## writting a conditional statement for our prediction
if prediction == '0':
    print('Sorry you are not elligible for the loan')
else:
    print('Congratulations you are eligible for loan')

# %%
Y

# %%
pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
python -m streamlit run Loan.py
# Out:
#   Cell In[180], line 1
#     python -m streamlit run Loan.py
#               ^
# SyntaxError: invalid syntax
